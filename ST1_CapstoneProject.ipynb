# %% [markdown]
# <a href="https://colab.research.google.com/github/Suba-XIV/ST1Capstone/blob/main/ST1_CapstoneProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ST1 ASSIGNMENT 9**
# # **CAPSTONE PROGRAMMING PROJECT**
# ### **u3238947**

# %% [markdown]
# The first 3 codes below are importing the datasets needed.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Capstone_Project_ST1/
# Out:
# /content/drive/MyDrive/Capstone_Project_ST1

# %%
# !ls
# Out:
# Netflix.csv

# %% [markdown]
# # This capstone Project is based on the Netflix Stock Price Prediction using Time Series. The data is available from the Kaggle repository: (https://www.kaggle.com/datasets/jainilcoder/netflix-stock-price-prediction/data)

# %% [markdown]
# # STEP 1: Reading the data set
#
# This step holds upmost significance to the completion of the project as understanding the data will allow me to perform further steps.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the dataset
import pandas as pd
import numpy as np
NetflixData=pd.read_csv('/content/drive/MyDrive/Capstone_Project_ST1/Netflix.csv', encoding='latin')
print('Shape before deleting duplicate values:', NetflixData.shape)

# Removing duplicate rows if any
NetflixData=NetflixData.drop_duplicates()
print('Shape After deleting duplicate values:', NetflixData.shape)

# Printing sample data
# Start observing the Quantitative/Categorical/Qualitative variables
NetflixData.head(10)
# Out:
# Shape before deleting duplicate values: (1009, 7)
# Shape After deleting duplicate values: (1009, 7)
#          Date        Open        High         Low       Close   Adj Close  \
# 0   5/02/2018  262.000000  267.899994  250.029999  254.259995  254.259995
# 1   6/02/2018  247.699997  266.700012  245.000000  265.720001  265.720001
# 2   7/02/2018  266.579987  272.450012  264.329987  264.559998  264.559998
# 3   8/02/2018  267.079987  267.619995  250.000000  250.100006  250.100006
# 4   9/02/2018  253.850006  255.800003  236.110001  249.470001  249.470001
# 5  12/02/2018  252.139999  259.149994  249.000000  257.950012  257.950012
# 6  13/02/2018  257.290009  261.410004  254.699997  258.269989  258.269989
# 7  14/02/2018  260.470001  269.880005  260.329987  266.000000  266.000000
# 8  15/02/2018  270.029999  280.500000  267.630005  280.269989  280.269989
# 9  16/02/2018  278.730011  281.959991  275.690002  278.519989  278.519989
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900
# 5   8534900
# 6   6855200
# 7  10972000
# 8  10759700
# 9   8312400
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_48['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_49['High'].plot(kind='hist', bins=20, title='High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_50['Low'].plot(kind='hist', bins=20, title='Low')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_51['Close'].plot(kind='hist', bins=20, title='Close')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_52.plot(kind='scatter', x='Open', y='High', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_53.plot(kind='scatter', x='High', y='Low', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_54.plot(kind='scatter', x='Low', y='Close', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_55.plot(kind='scatter', x='Close', y='Adj Close', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Date']
#   ys = series['Open']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_56.sort_values('Date', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Date')
# _ = plt.ylabel('Open')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Date']
#   ys = series['High']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_57.sort_values('Date', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Date')
# _ = plt.ylabel('High')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Date']
#   ys = series['Low']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_58.sort_values('Date', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Date')
# _ = plt.ylabel('Low')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Date']
#   ys = series['Close']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_59.sort_values('Date', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Date')
# _ = plt.ylabel('Close')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_60['Open'].plot(kind='line', figsize=(8, 4), title='Open')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_61['High'].plot(kind='line', figsize=(8, 4), title='High')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_62['Low'].plot(kind='line', figsize=(8, 4), title='Low')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_63['Close'].plot(kind='line', figsize=(8, 4), title='Close')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Open

from matplotlib import pyplot as plt
NetflixData['Open'].plot(kind='hist', bins=20, title='Open')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Key observations from step 1:
#
#
#
# *   The dataset spans 5 years (5th February 2018 - 5th February 2022
# *   There are 7 attributes in the data set;
#   *   Date:
#   *   Open:
#   *   High:
#   *   Low:
#   *   Close:
#   *   Adj Close:
#   *   Volume:

# %% [markdown]
# # STEP 2: Problem Statment Definition

# %% [markdown]
# # STEP 3: Target Variable Identification

# %% [markdown]
# # STEP 4: Visualising the distribution of Target variable

# %%
# %matplotlib inline
# Creating histogram as the Target variable is Continuous
# This will help us to understand the distribution of the PRICE values
NetflixData['Volume'].hist()
# Out:
# <Axes: >

# %%
# %matplotlib inline
# Creating histogram as the Target variable is Continuous
# This will help us to understand the distribution of the PRICE values
NetflixData['Open'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # STEP 5: Basic Level Data Exploration
